# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed

from inception_model_generator import MRNet_inc_model

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 20 epochs

# %%
label_type = 'ACL'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0.00001,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos

class_weight = {0: 1, 1: neg/pos}
if neg < pos:
  class_weight = {0: pos/neg, 1: 1}

print(class_weight)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l ,{0:1,1:1}, batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l,{0:1,1:1} ,batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)


model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/"+label_type+"/"+exam_view+"/weights.48.hdf5")
model.fit(x=train_data_gen, validation_data = test_data_gen,epochs=60, initial_epoch = 48,verbose=True, class_weight=class_weight,callbacks=[cbs[0]],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# no dropout
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# {0: 1, 1: 4.16243654822335}
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  train
# Combination:  ACL  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1017
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  test
# Combination:  ACL  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  113
# input size:  (299, 299)
# Epoch 49/60
# 1017/1017 [==============================] - 638s 627ms/step - loss: 0.3962 - tp: 96.8476 - fp: 8.8319 - tn: 401.9253 - fn: 1.3953 - accuracy: 0.9851 - precision: 0.9381 - recall: 0.9889 - auc: 0.9965 - val_loss: 0.1989 - val_tp: 194.9734 - val_fp: 25.6106 - val_tn: 845.2036 - val_fn: 8.2124 - val_accuracy: 0.9686 - val_precision: 0.8841 - val_recall: 0.9597 - val_auc: 0.9885
#
# Epoch 00049: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.49.hdf5
# Epoch 50/60
# 1017/1017 [==============================] - 542s 533ms/step - loss: 0.3276 - tp: 292.2281 - fp: 32.5556 - tn: 1303.2163 - fn: 11.0000 - accuracy: 0.9726 - precision: 0.8965 - recall: 0.9623 - auc: 0.9896 - val_loss: 0.1985 - val_tp: 394.7080 - val_fp: 34.9027 - val_tn: 1758.8319 - val_fn: 15.5575 - val_accuracy: 0.9771 - val_precision: 0.9188 - val_recall: 0.9621 - val_auc: 0.9898
#
# Epoch 00050: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.50.hdf5
# Epoch 51/60
# 1017/1017 [==============================] - 542s 533ms/step - loss: 0.3276 - tp: 292.2281 - fp: 32.5556 - tn: 1303.2163 - fn: 11.0000 - accuracy: 0.9726 - precision: 0.8965 - recall: 0.9623 - auc: 0.9896 - val_loss: 0.1985 - val_tp: 394.7080 - val_fp: 34.9027 - val_tn: 1758.8319 - val_fn: 15.5575 - val_accuracy: 0.9771 - val_precision: 0.9188 - val_recall: 0.9621 - val_auc: 0.9898
# 1017/1017 [==============================] - 542s 533ms/step - loss: 0.3212 - tp: 489.7975 - fp: 40.0000 - tn: 2219.2026 - fn: 20.0000 - accuracy: 0.9781 - precision: 0.9236 - recall: 0.9603 - auc: 0.9886 - val_loss: 0.1988 - val_tp: 594.6902 - val_fp: 44.1327 - val_tn: 2670.5132 - val_fn: 24.6637 - val_accuracy: 0.9794 - val_precision: 0.9309 - val_recall: 0.9602 - val_auc: 0.9884
#
# Epoch 00051: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.51.hdf5
# Epoch 52/60
# 1017/1017 [==============================] - 542s 533ms/step - loss: 0.3208 - tp: 697.0570 - fp: 47.0000 - tn: 3125.9429 - fn: 29.0000 - accuracy: 0.9804 - precision: 0.9365 - recall: 0.9598 - auc: 0.9890 - val_loss: 0.1985 - val_tp: 792.7079 - val_fp: 49.4248 - val_tn: 3587.4602 - val_fn: 34.4071 - val_accuracy: 0.9812 - val_precision: 0.9413 - val_recall: 0.9584 - val_auc: 0.9887
# 1017/1017 [==============================] - 542s 533ms/step - loss: 0.3212 - tp: 489.7975 - fp: 40.0000 - tn: 2219.2026 - fn: 20.0000 - accuracy: 0.9781 - precision: 0.9236 - recall: 0.9603 - auc: 0.9886 - val_loss: 0.1988 - val_tp: 594.6902 - val_fp: 44.1327 - val_tn: 2670.5132 - val_fn: 24.6637 - val_accuracy: 0.9794 - val_precision: 0.9309 - val_recall: 0.9602 - val_auc: 0.9884
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.52.hdf5
# Epoch 53/60
# 1017/1017 [==============================]
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.52.hdf5
# 1017/1017 [==============================] - 543s 533ms/step - loss: 0.3206 - tp: 882.6371 - fp: 54.0000 - tn: 4054.3628 - fn: 38.0000 - accuracy: 0.9816 - precision: 0.9422 - recall: 0.9586 - auc: 0.9889 - val_loss: 0.1985 - val_tp: 991.6460 - val_fp: 56.5398 - val_tn: 4501.7524 - val_fn: 44.0619 - val_accuracy: 0.9820 - val_precision: 0.9461 - val_recall: 0.9575 - val_auc: 0.9887
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.53.hdf5
# Epoch 54/60
# 1017/1017 [==============================] - 540s 531ms/step - loss: 0.3205 - tp: 1087.0029 - fp: 60.0000 - tn: 4964.9971 - fn: 47.0000 - accuracy: 0.9826 - precision: 0.9476 - recall: 0.9585 - auc: 0.9887 - val_loss: 0.1986 - val_tp: 1190.3717 - val_fp: 62.3274 - val_tn: 5418.0352 - val_fn: 53.2655 - val_accuracy: 0.9828 - val_precision: 0.9502 - val_recall: 0.9572 - val_auc: 0.9886
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.54.hdf5
# Epoch 55/60
# 1017/1017 [==============================] - 541s 532ms/step - loss: 0.4890 - tp: 1280.3491 - fp: 102.5565 - tn: 5843.3945 - fn: 62.7001 - accuracy: 0.9774 - precision: 0.9264 - recall: 0.9533 - auc: 0.9874 - val_loss: 0.4409 - val_tp: 1378.9381 - val_fp: 129.6726 - val_tn: 6274.9556 - val_fn: 70.4336 - val_accuracy: 0.9745 - val_precision: 0.9140 - val_recall: 0.9514 - val_auc: 0.9868
#
# Epoch 00055: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.55.hdf5
# Epoch 56/60
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3282 - tp: 1474.9438 - fp: 133.2805 - tn: 6734.2754 - fn: 76.0000 - accuracy: 0.9751 - precision: 0.9170 - recall: 0.9509 - auc: 0.9870
# 1017/1017 [==============================] - 542s 532ms/step - loss: 0.3281 - tp: 1475.0442 - fp: 133.2812 - tn: 6734.6743 - fn: 76.0000 - accuracy: 0.9751 - precision: 0.9170 - recall: 0.9509 - auc: 0.9870 - val_loss: 0.1988 - val_tp: 1580.0708 - val_fp: 137.9115 - val_tn: 7187.1152 - val_fn: 78.9027 - val_accuracy: 0.9759 - val_precision: 0.9197 - val_recall: 0.9524 - val_auc: 0.9875
#
# Epoch 00056: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.56.hdf5
# Epoch 57/60
# 1017/1017 [==============================] - 540s 531ms/step - loss: 0.3213 - tp: 1679.6863 - fp: 143.0000 - tn: 7644.3135 - fn: 82.0000 - accuracy: 0.9764 - precision: 0.9215 - recall: 0.9534 - auc: 0.9880 - val_loss: 0.1988 - val_tp: 1780.0531 - val_fp: 145.9557 - val_tn: 8100.8320 - val_fn: 87.1593 - val_accuracy: 0.9770 - val_precision: 0.9242 - val_recall: 0.9533 - val_auc: 0.9881
#
# Epoch 00057: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.57.hdf5
# Epoch 58/60
# 1017/1017 [==============================] - 541s 532ms/step - loss: 0.3205 - tp: 1879.2056 - fp: 148.0000 - tn: 8561.7949 - fn: 90.0000 - accuracy: 0.9777 - precision: 0.9269 - recall: 0.9543 - auc: 0.9885 - val_loss: 0.5221 - val_tp: 1980.3894 - val_fp: 150.3717 - val_tn: 9019.3535 - val_fn: 93.8850 - val_accuracy: 0.9783 - val_precision: 0.9294 - val_recall: 0.9547 - val_auc: 0.9887
#
# Epoch 00058: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.58.hdf5
# Epoch 59/60
# 1017/1017 [==============================] - 542s 533ms/step - loss: 0.3205 - tp: 2079.7366 - fp: 153.0000 - tn: 9478.2637 - fn: 98.0000 - accuracy: 0.9787 - precision: 0.9314 - recall: 0.9550 - auc: 0.9888 - val_loss: 0.1986 - val_tp: 2180.3008 - val_fp: 155.1947 - val_tn: 9935.5928 - val_fn: 102.9115 - val_accuracy: 0.9791 - val_precision: 0.9336 - val_recall: 0.9549 - val_auc: 0.9888
#
# Epoch 00059: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.59.hdf5
# Epoch 60/60
# 1017/1017 [==============================] - 542s 533ms/step - loss: 0.3205 - tp: 2276.5762 - fp: 158.0000 - tn: 10398.4238 - fn: 106.0000 - accuracy: 0.9796 - precision: 0.9351 - recall: 0.9555 - auc: 0.9891 - val_loss: 0.2001 - val_tp: 2380.1328 - val_fp: 159.4779 - val_tn: 10853.3896 - val_fn: 111.0000 - val_accuracy: 0.9800 - val_precision: 0.9372 - val_recall: 0.9554 - val_auc: 0.9893
#
# Epoch 00060: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/ACL/axial/weights.60.hdf5

# %% [markdown]
# # **testing on validation dataset**

# %%
label_type = 'ACL'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/"+label_type+"/"+exam_view+"/weights.51.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])

neg = total - pos
class_count_valid = {0: neg, 1: pos}

batch_size = 1
print(model.metrics_names)
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , batch_size=1,model="inception",data_type='valid', shuffle=False,label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
d = model.evaluate_generator(valid_data_gen, total, verbose=1)
print(d)
model.predict_generator(valid_data_gen, 5, verbose=1)
# Out:
# no dropout
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# ['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc']
# Initializing Data Generator:
# factor :  1.2222222222222223
# model:  inception
# data type:  valid
# Combination:  ACL  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (299, 299)
# 120/120 [==============================] - 60s 502ms/step
# [0.36452019214630127, 11.483333587646484, 2.133333444595337, 31.924999237060547, 14.958333015441895, 0.7441648840904236, 0.8863097429275513, 0.47476163506507874, 0.8348264098167419]
# 5/5 [==============================] - 3s 606ms/step
# array([[0.9428924 ],
#        [0.22147195],
#        [0.05008358],
#        [0.04197449],
#        [0.07244768]], dtype=float32)
