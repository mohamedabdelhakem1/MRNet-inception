# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed

from inception_model_generator import MRNet_inc_model

import tensorflow as tf
from sklearn.utils import class_weight
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 20 epochs

# %%
label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0.00001,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos

class_weight = {0: 1, 1: neg/pos}
if neg < pos:
  class_weight = {0: pos/neg, 1: 1}

print(class_weight)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l ,{0:1,1:1}, batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l,{0:1,1:1} ,batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)


model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/"+label_type+"/"+exam_view+"/weights.38.hdf5")
model.fit(x=train_data_gen, validation_data = test_data_gen,epochs=50, initial_epoch = 38,verbose=True, class_weight=class_weight,callbacks=[cbs[0]],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# no dropout
# no dropout
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_2 (MR (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# {0: 4.242268041237113, 1: 1}
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  train
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1017
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  test
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  113
# input size:  (299, 299)
# Epoch 39/50
# 1017/1017 [==============================] - 596s 586ms/step - loss: 0.5112 - tp: 382.8751 - fp: 3.2773 - tn: 91.1190 - fn: 31.7286 - accuracy: 0.9295 - precision: 0.9921 - recall: 0.9201 - auc: 0.9675 - val_loss: 0.1985 - val_tp: 780.4602 - val_fp: 10.7522 - val_tn: 195.2743 - val_fn: 87.5133 - val_accuracy: 0.9087 - val_precision: 0.9865 - val_recall: 0.8994 - val_auc: 0.9574
#
# Epoch 00039: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.39.hdf5
# Epoch 40/50
# 1017/1017 [==============================] - 527s 518ms/step - loss: 0.5322 - tp: 1181.0492 - fp: 19.0708 - tn: 292.5133 - fn: 146.3668 - accuracy: 0.8988 - precision: 0.9838 - recall: 0.8896 - auc: 0.9515 - val_loss: 0.4046 - val_tp: 1585.2655 - val_fp: 26.8142 - val_tn: 394.4513 - val_fn: 197.4690 - val_accuracy: 0.8983 - val_precision: 0.9834 - val_recall: 0.8892 - val_auc: 0.9510
#
# Epoch 00040: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.40.hdf5
# Epoch 41/50
#    1/1017 [..............................] - ETA: 9:04 - loss: 0.2150 - tp: 1621.0000 - fp: 35.0000 - tn: 399.0000 - fn: 206.0000 - accuracy: 0.8934 - precision: 0.9789 - recall: 0.8872 - auc: 0.9418
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 1 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 1017/1017 [==============================] - 559s 550ms/step - loss: 0.5125 - tp: 1997.1003 - fp: 37.3963 - tn: 491.7915 - fn: 242.7119 - accuracy: 0.8986 - precision: 0.9815 - recall: 0.8915 - auc: 0.9478 - val_loss: 0.2063 - val_tp: 2398.7256 - val_fp: 48.1239 - val_tn: 592.1770 - val_fn: 294.9734 - val_accuracy: 0.8971 - val_precision: 0.9803 - val_recall: 0.8905 - val_auc: 0.9459
#
# Epoch 00041: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.41.hdf5
# Epoch 42/50
# 1017/1017 [==============================] - 533s 524ms/step - loss: 0.5010 - tp: 2815.9685 - fp: 57.1603 - tn: 690.8967 - fn: 334.9744 - accuracy: 0.8994 - precision: 0.9800 - recall: 0.8937 - auc: 0.9470 - val_loss: 0.2105 - val_tp: 3222.1062 - val_fp: 68.6460 - val_tn: 788.1505 - val_fn: 385.0974 - val_accuracy: 0.8984 - val_precision: 0.9791 - val_recall: 0.8932 - val_auc: 0.9462
#
# Epoch 00042: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.42.hdf5
# Epoch 43/50
# 1017/1017 [==============================] - 531s 523ms/step - loss: 0.5041 - tp: 3630.7600 - fp: 78.4936 - tn: 890.7768 - fn: 428.9695 - accuracy: 0.8990 - precision: 0.9788 - recall: 0.8943 - auc: 0.9452 - val_loss: 0.2059 - val_tp: 4048.8230 - val_fp: 85.7611 - val_tn: 984.3363 - val_fn: 475.0797 - val_accuracy: 0.8997 - val_precision: 0.9793 - val_recall: 0.8950 - val_auc: 0.9456
#
# Epoch 00043: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.43.hdf5
# Epoch 44/50
# 1017/1017 [==============================] - 532s 523ms/step - loss: 0.4995 - tp: 4457.8340 - fp: 94.8092 - tn: 1091.7463 - fn: 514.6106 - accuracy: 0.9010 - precision: 0.9791 - recall: 0.8965 - auc: 0.9463 - val_loss: 2.2293 - val_tp: 4871.1768 - val_fp: 103.8496 - val_tn: 1186.6726 - val_fn: 562.3009 - val_accuracy: 0.9009 - val_precision: 0.9791 - val_recall: 0.8965 - val_auc: 0.9462
#
# Epoch 00044: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.44.hdf5
# Epoch 45/50
# 1017/1017 [==============================] - 531s 523ms/step - loss: 0.4772 - tp: 5279.5879 - fp: 112.7611 - tn: 1292.0669 - fn: 604.5840 - accuracy: 0.9015 - precision: 0.9791 - recall: 0.8972 - auc: 0.9468 - val_loss: 2.3438 - val_tp: 5705.3540 - val_fp: 123.4779 - val_tn: 1383.8938 - val_fn: 641.2744 - val_accuracy: 0.9026 - val_precision: 0.9788 - val_recall: 0.8990 - val_auc: 0.9470
#
# Epoch 00045: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.45.hdf5
# Epoch 46/50
# 1017/1017 [==============================] - 531s 522ms/step - loss: 0.5081 - tp: 6111.7158 - fp: 135.9794 - tn: 1479.4641 - fn: 691.8407 - accuracy: 0.9016 - precision: 0.9782 - recall: 0.8983 - auc: 0.9455 - val_loss: 0.3848 - val_tp: 6525.4160 - val_fp: 145.6814 - val_tn: 1577.3009 - val_fn: 735.6017 - val_accuracy: 0.9019 - val_precision: 0.9782 - val_recall: 0.8987 - val_auc: 0.9460
#
# Epoch 00046: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.46.hdf5
# Epoch 47/50
# 1017/1017 [==============================] - 531s 522ms/step - loss: 0.5114 - tp: 6936.9814 - fp: 155.7021 - tn: 1675.3776 - fn: 780.9390 - accuracy: 0.9019 - precision: 0.9780 - recall: 0.8988 - auc: 0.9462 - val_loss: 2.3061 - val_tp: 7338.6460 - val_fp: 161.2655 - val_tn: 1776.9381 - val_fn: 837.1505 - val_accuracy: 0.9013 - val_precision: 0.9785 - val_recall: 0.8976 - val_auc: 0.9459
#
# Epoch 00047: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.47.hdf5
# Epoch 48/50
# 1017/1017 [==============================] - 531s 523ms/step - loss: 0.4500 - tp: 7746.6733 - fp: 168.1554 - tn: 1885.9479 - fn: 878.2232 - accuracy: 0.9020 - precision: 0.9787 - recall: 0.8982 - auc: 0.9462 - val_loss: 0.3197 - val_tp: 8177.4692 - val_fp: 174.2035 - val_tn: 1981.2478 - val_fn: 911.0797 - val_accuracy: 0.9035 - val_precision: 0.9791 - val_recall: 0.8998 - val_auc: 0.9468
#
# Epoch 00048: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.48.hdf5
# Epoch 49/50
# 1017/1017 [==============================] - 532s 523ms/step - loss: 0.4799 - tp: 8590.9961 - fp: 185.9705 - tn: 2079.6440 - fn: 952.3894 - accuracy: 0.9036 - precision: 0.9788 - recall: 0.9002 - auc: 0.9469 - val_loss: 3.4623 - val_tp: 9012.7432 - val_fp: 193.4248 - val_tn: 2180.8762 - val_fn: 986.9557 - val_accuracy: 0.9046 - val_precision: 0.9790 - val_recall: 0.9013 - val_auc: 0.9476
#
# Epoch 00049: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.49.hdf5
# Epoch 50/50
# 1017/1017 [==============================] - 532s 523ms/step - loss: 0.4799 - tp: 8590.9961 - fp: 185.9705 - tn: 2079.6440 - fn: 952.3894 - accuracy: 0.9036 - precision: 0.9788 - recall: 0.9002 - auc: 0.9469 - val_loss: 3.4623 - val_tp: 9012.7432 - val_fp: 193.4248 - val_tn: 2180.8762 - val_fn: 986.9557 - val_accuracy: 0.9046 - val_precision: 0.9790 - val_recall: 0.9013 - val_auc: 0.9476
# 1017/1017 [==============================] - 533s 524ms/step - loss: 0.4664 - tp: 9426.9717 - fp: 204.6401 - tn: 2282.6323 - fn: 1024.7561 - accuracy: 0.9050 - precision: 0.9787 - recall: 0.9019 - auc: 0.9473 - val_loss: 0.3438 - val_tp: 9846.8057 - val_fp: 211.8673 - val_tn: 2378.9380 - val_fn: 1066.3894 - val_accuracy: 0.9053 - val_precision: 0.9789 - val_recall: 0.9023 - val_auc: 0.9478
#
# Epoch 00050: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/abnormal/axial/weights.50.hdf5

# %% [markdown]
# # **testing on validation dataset**

# %%
label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/"+label_type+"/"+exam_view+"/weights.50.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])

neg = total - pos
class_count_valid = {0: neg, 1: pos}

batch_size = 1
print(model.metrics_names)
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , batch_size=1,model="inception",data_type='valid', shuffle=False,label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
d = model.evaluate_generator(valid_data_gen, total, verbose=1)
print(d)
model.predict_generator(valid_data_gen, 5, verbose=1)
# Out:
# no dropout
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# ['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc']
# Initializing Data Generator:
# factor :  3.8
# model:  inception
# data type:  valid
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (299, 299)
# 120/120 [==============================] - 85s 709ms/step
# [0.2004963755607605, 44.56666564941406, 3.566666603088379, 8.983333587646484, 3.383333444595337, 0.870685338973999, 0.9092446565628052, 0.918715238571167, 0.8775835037231445]
# 5/5 [==============================] - 3s 563ms/step
# array([[0.9378059 ],
#        [0.9340859 ],
#        [0.960201  ],
#        [0.0269844 ],
#        [0.07042639]], dtype=float32)

# %%
  tp = 0
  tn = 0
  fp = 0
  fn = 0
  y_true = []
  y_score = []
  for i in range(len(valid_data_gen)):
    x, y = next(valid_data_gen)
    _y = model.predict_classes(x, batch_size=1, verbose=0)
    _y_score = model.predict_proba(x, batch_size=1)
    y_score.append(_y_score[0][0])
    y_true.append(y[0])
    if _y[0][0] == 1:
      if _y[0][0] == y[0]:
        tp += 1
      else:
        fp += 1
    else:
      if _y[0][0] == y[0]:
        tn += 1
      else:
        fn += 1
  precision = tp / (tp +fp)
  recall = tp / (tp + fn)
  f1 = 2*((precision*recall)/(precision+recall))
  y_score = np.array(y_score)
  y_true = np.array(y_true)
  fpr, tpr, _ = roc_curve(y_true, y_score)
  auc = roc_auc(fpr, tpr)
  print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(valid_data_gen)), " F1 = ", f1, " auc = ", auc)
# Out:
# tp =  85  fp =  8  tn =  17  fn =  10  accuracy =  0.85  F1 =  0.9042553191489361  auc =  0.8690526315789473
