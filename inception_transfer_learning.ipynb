# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed

from transfer_inception import MRNet_inc_model

import tensorflow as tf

from sklearn.utils import class_weight
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 20 epochs

# %%
label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0.000001,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos

class_weight = {0: 1, 1: pos/neg}
if neg < pos:
  class_weight = {0: pos/neg, 1: 1}


print(class_weight)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l ,{0:1,1:1}, batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l,{0:1,1:1} ,batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)


model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/"+label_type+"/"+exam_view+"/weights.51.hdf5")
model.fit(x=train_data_gen, epochs=60, initial_epoch = 51,verbose=True, class_weight=class_weight,callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# (None, 299, 299, 3)
# no dropout
# (None, 299, 299, 3)
# no dropout
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_transfer_2  (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# {0: 4.242268041237113, 1: 1}
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  train
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1017
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  test
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  113
# input size:  (299, 299)
# Epoch 52/60
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3422 - tp: 413.6250 - fp: 0.0000e+00 - tn: 94.8750 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.9980Epoch 52/60
# 1017/1017 [==============================] - 540s 531ms/step - loss: 0.3427 - tp: 414.0275 - fp: 0.0000e+00 - tn: 94.9725 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 0.9980
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.52.hdf5
# Epoch 53/60
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.3368 - tp: 1235.0315 - fp: 0.0000e+00 - tn: 290.9685 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.53.hdf5
# Epoch 54/60
# 1017/1017 [==============================] - 481s 473ms/step - loss: 0.3379 - tp: 2060.8103 - fp: 0.0000e+00 - tn: 482.1898 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.54.hdf5
# Epoch 55/60
# 1017/1017 [==============================] - 482s 474ms/step - loss: 0.3389 - tp: 2876.3059 - fp: 0.0000e+00 - tn: 683.6942 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00055: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.55.hdf5
# Epoch 56/60
# 1017/1017 [==============================] - 481s 473ms/step - loss: 0.3389 - tp: 3698.6567 - fp: 0.0000e+00 - tn: 878.3431 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00056: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.56.hdf5
# Epoch 57/60
# 1017/1017 [==============================] - 481s 473ms/step - loss: 0.3350 - tp: 4529.0444 - fp: 0.0000e+00 - tn: 1064.9558 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00057: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.57.hdf5
# Epoch 58/60
# 1017/1017 [==============================] - 482s 474ms/step - loss: 0.3349 - tp: 5355.2466 - fp: 0.0000e+00 - tn: 1255.7532 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00058: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.58.hdf5
# Epoch 59/60
# 1017/1017 [==============================] - 481s 473ms/step - loss: 0.3314 - tp: 6166.9746 - fp: 0.0000e+00 - tn: 1461.0255 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00059: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.59.hdf5
# Epoch 60/60
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.3296 - tp: 6991.1748 - fp: 0.0000e+00 - tn: 1653.8250 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#
# Epoch 00060: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.60.hdf5

# %%
label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0.000001,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos

class_weight = {0: 1, 1: pos/neg}
if neg < pos:
  class_weight = {0: pos/neg, 1: 1}


print(class_weight)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l ,{0:1,1:1}, batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l,{0:1,1:1} ,batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)


model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/"+label_type+"/"+exam_view+"/weights.39.hdf5")
model.fit(x=train_data_gen, epochs=50, initial_epoch = 39,verbose=True, class_weight=class_weight,callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# (None, 299, 299, 3)
# no dropout
# (None, 299, 299, 3)
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_transfer_1  (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# {0: 4.242268041237113, 1: 1}
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  train
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1017
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  test
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  113
# input size:  (299, 299)
# Epoch 40/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 1.0818 - tp: 265.1703 - fp: 39.3218 - tn: 60.6191 - fn: 143.3888 - accuracy: 0.6323 - precision: 0.8547 - recall: 0.6456 - auc: 0.6317
# 1017/1017 [==============================] - 559s 549ms/step - loss: 1.0810 - tp: 265.4553 - fp: 39.3500 - tn: 60.6834 - fn: 143.5113 - accuracy: 0.6323 - precision: 0.8548 - recall: 0.6456 - auc: 0.6317
#
# Epoch 00040: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.40.hdf5
# Epoch 41/50
# 1017/1017 [==============================] - 483s 475ms/step - loss: 0.8343 - tp: 863.5949 - fp: 89.0324 - tn: 201.2212 - fn: 372.1514 - accuracy: 0.6950 - precision: 0.9050 - recall: 0.6963 - auc: 0.7606
#
# Epoch 00041: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.41.hdf5
# Epoch 42/50
# 1017/1017 [==============================] - 482s 474ms/step - loss: 0.7221 - tp: 1510.5300 - fp: 118.9380 - tn: 364.9646 - fn: 548.5674 - accuracy: 0.7365 - precision: 0.9265 - recall: 0.7327 - auc: 0.8184
#
# Epoch 00042: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.42.hdf5
# Epoch 43/50
# 1017/1017 [==============================] - 481s 473ms/step - loss: 0.6194 - tp: 2196.9763 - fp: 137.0757 - tn: 544.4739 - fn: 681.4739 - accuracy: 0.7694 - precision: 0.9409 - recall: 0.7626 - auc: 0.8580
#
# Epoch 00043: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.43.hdf5
# Epoch 44/50
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.5510 - tp: 2918.5222 - fp: 145.8741 - tn: 727.8073 - fn: 784.7964 - accuracy: 0.7962 - precision: 0.9522 - recall: 0.7877 - auc: 0.8870
#
# Epoch 00044: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.44.hdf5
# Epoch 45/50
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.4884 - tp: 3670.2173 - fp: 149.9843 - tn: 909.3668 - fn: 864.4316 - accuracy: 0.8183 - precision: 0.9606 - recall: 0.8091 - auc: 0.9091
#
# Epoch 00045: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.45.hdf5
# Epoch 46/50
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.4304 - tp: 4442.1377 - fp: 151.0000 - tn: 1103.6804 - fn: 914.1819 - accuracy: 0.8386 - precision: 0.9670 - recall: 0.8291 - auc: 0.9274
#
# Epoch 00046: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.46.hdf5
# Epoch 47/50
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.3900 - tp: 5240.2832 - fp: 151.0000 - tn: 1300.1652 - fn: 936.5516 - accuracy: 0.8572 - precision: 0.9719 - recall: 0.8482 - auc: 0.9422
#
# Epoch 00047: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.47.hdf5
# Epoch 48/50
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.3692 - tp: 6052.1357 - fp: 151.0000 - tn: 1494.7050 - fn: 947.1593 - accuracy: 0.8728 - precision: 0.9756 - recall: 0.8645 - auc: 0.9534
#
# Epoch 00048: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.48.hdf5
# Epoch 49/50
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.3528 - tp: 6863.3501 - fp: 151.0000 - tn: 1697.4583 - fn: 950.1917 - accuracy: 0.8859 - precision: 0.9784 - recall: 0.8783 - auc: 0.9620
#
# Epoch 00049: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.49.hdf5
# Epoch 50/50
# 1017/1017 [==============================] - 480s 472ms/step - loss: 0.3449 - tp: 7690.1978 - fp: 151.0000 - tn: 1886.8024 - fn: 951.0000 - accuracy: 0.8967 - precision: 0.9807 - recall: 0.8899 - auc: 0.9684
#
# Epoch 00050: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/abnormal/axial/weights.50.hdf5

# %% [markdown]
# # **testing on validation dataset**

# %%
label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_transfer/"+label_type+"/"+exam_view+"/weights.54.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])

neg = total - pos
class_count_valid = {0: neg, 1: pos}

batch_size = 1
print(model.metrics_names)
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , batch_size=1,model="inception",data_type='train', shuffle=False,label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
d = model.evaluate_generator(valid_data_gen, total, verbose=1)
print(d)
model.predict_generator(valid_data_gen, total, verbose=1)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 8s 0us/step
# (None, 299, 299, 3)
# no dropout
# (None, 299, 299, 3)
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_transfer_1  (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# ['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc']
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  inception
# data type:  train
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (299, 299)
# 1017/1017 [==============================] - 1070s 1s/step
# [0.20288130640983582, 414.2664794921875, 0.0, 94.73352813720703, 0.0, 1.0, 1.0, 1.0, 0.9960668683052063]
# 1017/1017 [==============================] - 205s 202ms/step
# array([[0.97672504],
#        [0.9393691 ],
#        [0.91844237],
#        ...,
#        [0.93415236],
#        [0.03130892],
#        [0.9677972 ]], dtype=float32)

# %%
  tp = 0
  tn = 0
  fp = 0
  fn = 0
  y_true = []
  y_score = []
  for i in range(len(valid_data_gen)):
    x, y = next(valid_data_gen)
    _y = model.predict_classes(x, batch_size=1, verbose=0)
    _y_score = model.predict_proba(x, batch_size=1)
    y_score.append(_y_score[0][0])
    y_true.append(y[0])
    if _y[0][0] == 1:
      if _y[0][0] == y[0]:
        tp += 1
      else:
        fp += 1
    else:
      if _y[0][0] == y[0]:
        tn += 1
      else:
        fn += 1
  precision = tp / (tp +fp)
  recall = tp / (tp + fn)
  f1 = 2*((precision*recall)/(precision+recall))
  y_score = np.array(y_score)
  y_true = np.array(y_true)
  fpr, tpr, _ = roc_curve(y_true, y_score)
  auc = roc_auc(fpr, tpr)
  print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(valid_data_gen)), " F1 = ", f1, " auc = ", auc)
# Out:
# tp =  823  fp =  0  tn =  823  fn =  0  accuracy =  1.0  F1 =  1.0  auc =  0.9999999999999999
