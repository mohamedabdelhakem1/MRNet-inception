# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed

from inception_model_generator import MRNet_inc_model

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 20 epochs

# %%
label_type = 'meniscus'
exam_view = 'coronal'
model, cbs = MRNet_inc_model(1,0.00001,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos

class_weight = {0: 1, 1: neg/pos}
if neg < pos:
  class_weight = {0: pos/neg, 1: 1}

print(class_weight)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l ,{0:1,1:1}, batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l,{0:1,1:1} ,batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)


model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/"+label_type+"/"+exam_view+"/weights.50.hdf5")
model.fit(x=train_data_gen, validation_data = test_data_gen,epochs=75, initial_epoch =50,verbose=True, class_weight=class_weight,callbacks=[cbs[0]],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# no dropout
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# {0: 1, 1: 1.778688524590164}
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  train
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1017
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  test
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  113
# input size:  (299, 299)
# Epoch 51/75
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3115 - tp: 173.4419 - fp: 3.7372 - tn: 328.1782 - fn: 3.1427 - accuracy: 0.9867 - precision: 0.9820 - recall: 0.9774 - auc: 0.9982Epoch 51/75
# 1017/1017 [==============================] - 1004s 987ms/step - loss: 0.3114 - tp: 173.6264 - fp: 3.7414 - tn: 328.4877 - fn: 3.1445 - accuracy: 0.9867 - precision: 0.9820 - recall: 0.9774 - auc: 0.9982 - val_loss: 0.2003 - val_tp: 370.9911 - val_fp: 20.9204 - val_tn: 670.4956 - val_fn: 11.5929 - val_accuracy: 0.9700 - val_precision: 0.9473 - val_recall: 0.9699 - val_auc: 0.9838
#
# Epoch 00051: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.51.hdf5
# Epoch 52/75
# 1017/1017 [==============================] - 1004s 987ms/step - loss: 0.3114 - tp: 173.6264 - fp: 3.7414 - tn: 328.4877 - fn: 3.1445 - accuracy: 0.9867 - precision: 0.9820 - recall: 0.9774 - auc: 0.9982 - val_loss: 0.2003 - val_tp: 370.9911 - val_fp: 20.9204 - val_tn: 670.4956 - val_fn: 11.5929 - val_accuracy: 0.9700 - val_precision: 0.9473 - val_recall: 0.9699 - val_auc: 0.9838
# 1017/1017 [==============================] - 755s 742ms/step - loss: 0.3240 - tp: 559.7660 - fp: 37.9931 - tn: 1020.5526 - fn: 20.6883 - accuracy: 0.9639 - precision: 0.9361 - recall: 0.9638 - auc: 0.9789 - val_loss: 0.2607 - val_tp: 744.5309 - val_fp: 57.3894 - val_tn: 1369.8938 - val_fn: 32.1858 - val_accuracy: 0.9594 - val_precision: 0.9285 - val_recall: 0.9586 - val_auc: 0.9772
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.52.hdf5
# Epoch 53/75
# 1017/1017 [==============================] - 755s 743ms/step - loss: 0.3048 - tp: 933.0020 - fp: 67.8800 - tn: 1725.8456 - fn: 42.2724 - accuracy: 0.9599 - precision: 0.9317 - recall: 0.9562 - auc: 0.9771 - val_loss: 0.8486 - val_tp: 1126.5398 - val_fp: 91.1947 - val_tn: 2065.9380 - val_fn: 50.3274 - val_accuracy: 0.9576 - val_precision: 0.9252 - val_recall: 0.9573 - val_auc: 0.9766
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.53.hdf5
# Epoch 54/75
# 1017/1017 [==============================] - 754s 742ms/step - loss: 0.3375 - tp: 1315.6696 - fp: 117.6775 - tn: 2407.3826 - fn: 58.2704 - accuracy: 0.9548 - precision: 0.9178 - recall: 0.9575 - auc: 0.9760 - val_loss: 0.2063 - val_tp: 1502.5487 - val_fp: 145.7345 - val_tn: 2745.7876 - val_fn: 69.9292 - val_accuracy: 0.9517 - val_precision: 0.9116 - val_recall: 0.9555 - val_auc: 0.9743
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.54.hdf5
# Epoch 55/75
# 1017/1017 [==============================] - 755s 742ms/step - loss: 0.2825 - tp: 1698.6726 - fp: 158.9734 - tn: 3093.5742 - fn: 77.7797 - accuracy: 0.9528 - precision: 0.9141 - recall: 0.9561 - auc: 0.9744 - val_loss: 0.6915 - val_tp: 1884.2832 - val_fp: 173.8673 - val_tn: 3448.9116 - val_fn: 86.9380 - val_accuracy: 0.9534 - val_precision: 0.9155 - val_recall: 0.9559 - val_auc: 0.9745
#
# Epoch 00055: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.55.hdf5
# Epoch 56/75
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3253 - tp: 2070.1575 - fp: 193.2972 - tn: 3799.4282 - fn: 95.6171 - accuracy: 0.9531 - precision: 0.9145 - recall: 0.9558 - auc: 0.9747
# 1017/1017 [==============================] - 756s 743ms/step - loss: 0.3253 - tp: 2070.3333 - fp: 193.3087 - tn: 3799.7346 - fn: 95.6234 - accuracy: 0.9531 - precision: 0.9145 - recall: 0.9558 - auc: 0.9747 - val_loss: 2.6463 - val_tp: 2254.5664 - val_fp: 214.7434 - val_tn: 4141.8408 - val_fn: 112.8496 - val_accuracy: 0.9513 - val_precision: 0.9130 - val_recall: 0.9523 - val_auc: 0.9745
#
# Epoch 00056: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.56.hdf5
# Epoch 57/75
# 1017/1017 [==============================] - 757s 745ms/step - loss: 0.2818 - tp: 2434.7827 - fp: 224.3402 - tn: 4507.8770 - fn: 122.0000 - accuracy: 0.9524 - precision: 0.9155 - recall: 0.9522 - auc: 0.9750 - val_loss: 2.4271 - val_tp: 2635.6726 - val_fp: 235.1770 - val_tn: 4854.2124 - val_fn: 128.9380 - val_accuracy: 0.9536 - val_precision: 0.9181 - val_recall: 0.9534 - val_auc: 0.9756
#
# Epoch 00057: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.57.hdf5
# Epoch 58/75
# 1017/1017 [==============================] - 756s 743ms/step - loss: 0.3047 - tp: 2838.4729 - fp: 248.6224 - tn: 5194.9478 - fn: 136.9567 - accuracy: 0.9542 - precision: 0.9194 - recall: 0.9539 - auc: 0.9758 - val_loss: 0.2065 - val_tp: 3012.5044 - val_fp: 269.1859 - val_tn: 5552.6284 - val_fn: 149.6814 - val_accuracy: 0.9534 - val_precision: 0.9180 - val_recall: 0.9527 - val_auc: 0.9760
#
# Epoch 00057: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.57.hdf5
#
# Epoch 00058: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.58.hdf5
# Epoch 59/75
# 1017/1017 [==============================] - 756s 743ms/step - loss: 0.3447 - tp: 3194.2085 - fp: 303.9685 - tn: 5884.6509 - fn: 166.1721 - accuracy: 0.9507 - precision: 0.9131 - recall: 0.9505 - auc: 0.9756 - val_loss: 0.1987 - val_tp: 3379.9026 - val_fp: 317.8318 - val_tn: 6240.7788 - val_fn: 175.4867 - val_accuracy: 0.9512 - val_precision: 0.9141 - val_recall: 0.9506 - val_auc: 0.9759
#
# Epoch 00059: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.59.hdf5
# Epoch 60/75
# 1017/1017 [==============================] - 757s 745ms/step - loss: 0.3003 - tp: 3563.9006 - fp: 329.2153 - tn: 6600.5410 - fn: 185.3432 - accuracy: 0.9518 - precision: 0.9154 - recall: 0.9505 - auc: 0.9759 - val_loss: 0.2951 - val_tp: 3758.6992 - val_fp: 346.0089 - val_tn: 6945.0796 - val_fn: 194.2124 - val_accuracy: 0.9520 - val_precision: 0.9157 - val_recall: 0.9509 - val_auc: 0.9759
#
# Epoch 00060: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.60.hdf5
# Epoch 61/75
# 1017/1017 [==============================] - 757s 744ms/step - loss: 0.2832 - tp: 3942.7090 - fp: 355.6942 - tn: 7305.0698 - fn: 205.5270 - accuracy: 0.9524 - precision: 0.9172 - recall: 0.9504 - auc: 0.9756 - val_loss: 0.1988 - val_tp: 4137.9204 - val_fp: 366.0974 - val_tn: 7656.4956 - val_fn: 213.4867 - val_accuracy: 0.9532 - val_precision: 0.9187 - val_recall: 0.9509 - val_auc: 0.9757
#
# Epoch 00061: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.61.hdf5
# Epoch 62/75
# 1017/1017 [==============================] - 756s 744ms/step - loss: 0.2684 - tp: 4334.1699 - fp: 376.0000 - tn: 8006.8301 - fn: 222.0000 - accuracy: 0.9538 - precision: 0.9201 - recall: 0.9512 - auc: 0.9757 - val_loss: 0.2582 - val_tp: 4520.0264 - val_fp: 385.8141 - val_tn: 8368.2744 - val_fn: 229.8849 - val_accuracy: 0.9544 - val_precision: 0.9214 - val_recall: 0.9516 - val_auc: 0.9760
#
# Epoch 00062: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.62.hdf5
# Epoch 63/75
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3094 - tp: 4711.9204 - fp: 405.3593 - tn: 8709.6465 - fn: 241.5738 - accuracy: 0.9540 - precision: 0.9208 - recall: 0.9512 - auc: 0.9758
# 1017/1017 [==============================] - 756s 744ms/step - loss: 0.2684 - tp: 4334.1699 - fp: 376.0000 - tn: 8006.8301 - fn: 222.0000 - accuracy: 0.9538 - precision: 0.9201 - recall: 0.9512 - auc: 0.9757 - val_loss: 0.2582 - val_tp: 4520.0264 - val_fp: 385.8141 - val_tn: 8368.2744 - val_fn: 229.8849 - val_accuracy: 0.9544 - val_precision: 0.9214 - val_recall: 0.9516 - val_auc: 0.9760
# 1017/1017 [==============================] - 757s 744ms/step - loss: 0.3095 - tp: 4712.0933 - fp: 405.3618 - tn: 8709.9707 - fn: 241.5742 - accuracy: 0.9540 - precision: 0.9208 - recall: 0.9512 - auc: 0.9758 - val_loss: 2.3339 - val_tp: 4895.5840 - val_fp: 418.2832 - val_tn: 9071.0352 - val_fn: 249.0974 - val_accuracy: 0.9544 - val_precision: 0.9213 - val_recall: 0.9516 - val_auc: 0.9758
#
# Epoch 00063: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.63.hdf5
# Epoch 64/75
# 1017/1017 [==============================] - 757s 744ms/step - loss: 0.3269 - tp: 5085.4629 - fp: 433.0511 - tn: 9422.3857 - fn: 258.1003 - accuracy: 0.9545 - precision: 0.9215 - recall: 0.9517 - auc: 0.9757 - val_loss: 0.2261 - val_tp: 5268.8760 - val_fp: 467.1062 - val_tn: 9755.8057 - val_fn: 272.2124 - val_accuracy: 0.9531 - val_precision: 0.9186 - val_recall: 0.9509 - val_auc: 0.9754
#
# Epoch 00064: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.64.hdf5
# Epoch 65/75
# 1017/1017 [==============================] - 758s 745ms/step - loss: 0.3157 - tp: 5464.0845 - fp: 488.0875 - tn: 10093.3096 - fn: 283.5182 - accuracy: 0.9527 - precision: 0.9180 - recall: 0.9507 - auc: 0.9752 - val_loss: 0.2058 - val_tp: 5645.7168 - val_fp: 502.1239 - val_tn: 10452.4160 - val_fn: 293.7434 - val_accuracy: 0.9529 - val_precision: 0.9183 - val_recall: 0.9505 - val_auc: 0.9752
#
# Epoch 00065: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.65.hdf5
# Epoch 66/75
# 1017/1017 [==============================] - 759s 746ms/step - loss: 0.2670 - tp: 5834.7275 - fp: 511.0000 - tn: 10810.2725 - fn: 303.0000 - accuracy: 0.9534 - precision: 0.9195 - recall: 0.9506 - auc: 0.9754 - val_loss: 0.2014 - val_tp: 6023.8584 - val_fp: 520.1328 - val_tn: 11167.3721 - val_fn: 312.6372 - val_accuracy: 0.9538 - val_precision: 0.9205 - val_recall: 0.9507 - val_auc: 0.9757
#
# Epoch 00066: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.66.hdf5
# Epoch 67/75
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.2633 - tp: 6207.8296 - fp: 530.0000 - tn: 11530.6699 - fn: 320.0000 - accuracy: 0.9543 - precision: 0.9213 - recall: 0.9510 - auc: 0.9759
# Epoch 00066: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.66.hdf5
# 1017/1017 [==============================] - 759s 746ms/step - loss: 0.2634 - tp: 6208.0166 - fp: 530.0000 - tn: 11530.9834 - fn: 320.0000 - accuracy: 0.9543 - precision: 0.9213 - recall: 0.9510 - auc: 0.9759 - val_loss: 3.3978 - val_tp: 6403.6548 - val_fp: 534.2213 - val_tn: 11886.0801 - val_fn: 330.0443 - val_accuracy: 0.9549 - val_precision: 0.9230 - val_recall: 0.9510 - val_auc: 0.9761
#
# Epoch 00067: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.67.hdf5
# Epoch 68/75
# 1017/1017 [==============================] - 759s 746ms/step - loss: 0.3148 - tp: 6580.1289 - fp: 553.4415 - tn: 12235.5312 - fn: 349.8987 - accuracy: 0.9542 - precision: 0.9224 - recall: 0.9495 - auc: 0.9760 - val_loss: 0.2045 - val_tp: 6771.8672 - val_fp: 568.8318 - val_tn: 12583.6191 - val_fn: 359.6814 - val_accuracy: 0.9542 - val_precision: 0.9225 - val_recall: 0.9496 - val_auc: 0.9760
#
# Epoch 00068: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.68.hdf5
# Epoch 69/75
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.2651 - tp: 6958.6309 - fp: 581.0000 - tn: 12942.8691 - fn: 366.0000 - accuracy: 0.9546 - precision: 0.9229 - recall: 0.9500 - auc: 0.9762
# Epoch 00068: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.68.hdf5
# 1017/1017 [==============================] - 760s 747ms/step - loss: 0.2652 - tp: 6958.8149 - fp: 581.0000 - tn: 12943.1846 - fn: 366.0000 - accuracy: 0.9546 - precision: 0.9229 - recall: 0.9500 - auc: 0.9762 - val_loss: 2.6310 - val_tp: 7155.5308 - val_fp: 599.8938 - val_tn: 13287.4688 - val_fn: 371.1062 - val_accuracy: 0.9547 - val_precision: 0.9227 - val_recall: 0.9507 - val_auc: 0.9762
#
# Epoch 00069: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.69.hdf5
# Epoch 70/75
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3053 - tp: 7345.7183 - fp: 622.8593 - tn: 13629.1113 - fn: 380.8110 - accuracy: 0.9543 - precision: 0.9218 - recall: 0.9507 - auc: 0.9763
# Epoch 00069: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.69.hdf5
# 1017/1017 [==============================] - 761s 748ms/step - loss: 0.3052 - tp: 7345.8970 - fp: 622.8613 - tn: 13629.4297 - fn: 380.8122 - accuracy: 0.9543 - precision: 0.9218 - recall: 0.9507 - auc: 0.9763 - val_loss: 2.6968 - val_tp: 7535.9116 - val_fp: 636.3629 - val_tn: 13983.5664 - val_fn: 388.1593 - val_accuracy: 0.9546 - val_precision: 0.9221 - val_recall: 0.9510 - val_auc: 0.9765
#
# Epoch 00070: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.70.hdf5
# Epoch 71/75
# 1017/1017 [==============================] - 761s 748ms/step - loss: 0.2634 - tp: 7726.5479 - fp: 649.0000 - tn: 14338.4521 - fn: 395.0000 - accuracy: 0.9548 - precision: 0.9225 - recall: 0.9514 - auc: 0.9766 - val_loss: 3.4947 - val_tp: 7919.7612 - val_fp: 661.5929 - val_tn: 14687.7432 - val_fn: 404.9026 - val_accuracy: 0.9550 - val_precision: 0.9229 - val_recall: 0.9514 - val_auc: 0.9765
#
# Epoch 00071: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.71.hdf5
# Epoch 72/75
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.2606 - tp: 8117.6133 - fp: 672.0000 - tn: 15038.8867 - fn: 410.0000 - accuracy: 0.9554 - precision: 0.9235 - recall: 0.9519 - auc: 0.9767
# Epoch 00071: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.71.hdf5
# 1017/1017 [==============================] - 762s 749ms/step - loss: 0.2606 - tp: 8117.7856 - fp: 672.0000 - tn: 15039.2148 - fn: 410.0000 - accuracy: 0.9554 - precision: 0.9235 - recall: 0.9519 - auc: 0.9767 - val_loss: 1.3006 - val_tp: 8300.0088 - val_fp: 682.9646 - val_tn: 15403.4512 - val_fn: 417.5752 - val_accuracy: 0.9556 - val_precision: 0.9240 - val_recall: 0.9521 - val_auc: 0.9769
#
# Epoch 00072: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.72.hdf5
# Epoch 73/75
# 1017/1017 [==============================] - 760s 747ms/step - loss: 0.3449 - tp: 8476.1699 - fp: 707.9312 - tn: 15752.6455 - fn: 432.2537 - accuracy: 0.9551 - precision: 0.9229 - recall: 0.9515 - auc: 0.9768 - val_loss: 1.4583 - val_tp: 8670.6992 - val_fp: 732.0797 - val_tn: 16088.3359 - val_fn: 442.8849 - val_accuracy: 0.9547 - val_precision: 0.9221 - val_recall: 0.9514 - val_auc: 0.9768
#
# Epoch 00073: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.73.hdf5
# Epoch 74/75
# 1017/1017 [==============================] - 759s 746ms/step - loss: 0.2667 - tp: 8864.4160 - fp: 742.0000 - tn: 16442.5840 - fn: 450.0000 - accuracy: 0.9550 - precision: 0.9227 - recall: 0.9517 - auc: 0.9769 - val_loss: 0.2026 - val_tp: 9056.9736 - val_fp: 754.3186 - val_tn: 16796.0527 - val_fn: 456.6549 - val_accuracy: 0.9553 - val_precision: 0.9231 - val_recall: 0.9520 - val_auc: 0.9770
#
# Epoch 00074: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.74.hdf5
# Epoch 75/75
# 1017/1017 [==============================] - 759s 746ms/step - loss: 0.2615 - tp: 9245.1680 - fp: 769.0000 - tn: 17151.8223 - fn: 463.0000 - accuracy: 0.9554 - precision: 0.9232 - recall: 0.9523 - auc: 0.9771 - val_loss: 2.6775 - val_tp: 9438.0801 - val_fp: 778.1416 - val_tn: 17507.6992 - val_fn: 470.0797 - val_accuracy: 0.9557 - val_precision: 0.9238 - val_recall: 0.9526 - val_auc: 0.9773
#
# Epoch 00075: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.75.hdf5

# %%
label_type = 'meniscus'
exam_view = 'coronal'
model, cbs = MRNet_inc_model(1,0.00001,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos

class_weight = {0: 1, 1: neg/pos}
if neg < pos:
  class_weight = {0: pos/neg, 1: 1}

print(class_weight)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l ,{0:1,1:1}, batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l,{0:1,1:1} ,batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)


model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/"+label_type+"/"+exam_view+"/weights.30.hdf5")
model.fit(x=train_data_gen, validation_data = test_data_gen,epochs=50, initial_epoch = 30,verbose=True, class_weight=class_weight,callbacks=[cbs[0]],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# no dropout
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# {0: 1, 1: 1.778688524590164}
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  train
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1017
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  1.0
# model:  inception
# data type:  test
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  113
# input size:  (299, 299)
# Epoch 31/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.6722 - tp: 146.1919 - fp: 72.4321 - tn: 251.4931 - fn: 38.3829 - accuracy: 0.7846 - precision: 0.6760 - recall: 0.7964 - auc: 0.8648Epoch 31/50
# 1017/1017 [==============================] - 1033s 1s/step - loss: 0.6718 - tp: 146.3274 - fp: 72.5074 - tn: 251.7394 - fn: 38.4258 - accuracy: 0.7846 - precision: 0.6760 - recall: 0.7964 - auc: 0.8648 - val_loss: 0.3090 - val_tp: 291.2036 - val_fp: 163.4071 - val_tn: 530.6725 - val_fn: 88.7168 - val_accuracy: 0.7654 - val_precision: 0.6408 - val_recall: 0.7666 - val_auc: 0.8436
#
# Epoch 00031: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.31.hdf5
# Epoch 32/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.6550 - tp: 451.9085 - fp: 242.0463 - tn: 810.7028 - fn: 133.8425 - accuracy: 0.7702 - precision: 0.6504 - recall: 0.7708 - auc: 0.8467
# Epoch 00031: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.31.hdf5
# 1017/1017 [==============================] - 775s 762ms/step - loss: 0.6546 - tp: 452.0384 - fp: 242.1180 - tn: 810.9567 - fn: 133.8869 - accuracy: 0.7702 - precision: 0.6504 - recall: 0.7708 - auc: 0.8467 - val_loss: 0.2039 - val_tp: 590.0354 - val_fp: 325.9557 - val_tn: 1100.5664 - val_fn: 187.4425 - val_accuracy: 0.7671 - val_precision: 0.6442 - val_recall: 0.7590 - val_auc: 0.8470
#
# Epoch 00032: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.32.hdf5
# Epoch 33/50
# 1017/1017 [==============================] - 775s 762ms/step - loss: 0.6546 - tp: 452.0384 - fp: 242.1180 - tn: 810.9567 - fn: 133.8869 - accuracy: 0.7702 - precision: 0.6504 - recall: 0.7708 - auc: 0.8467 - val_loss: 0.2039 - val_tp: 590.0354 - val_fp: 325.9557 - val_tn: 1100.5664 - val_fn: 187.4425 - val_accuracy: 0.7671 - val_precision: 0.6442 - val_recall: 0.7590 - val_auc: 0.8470
# 1017/1017 [==============================] - 775s 762ms/step - loss: 0.6291 - tp: 741.8486 - fp: 397.7561 - tn: 1398.3972 - fn: 230.9980 - accuracy: 0.7725 - precision: 0.6503 - recall: 0.7621 - auc: 0.8505 - val_loss: 1.7547 - val_tp: 904.5398 - val_fp: 482.6106 - val_tn: 1673.2389 - val_fn: 273.6106 - val_accuracy: 0.7732 - val_precision: 0.6521 - val_recall: 0.7678 - val_auc: 0.8531
#
# Epoch 00033: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.33.hdf5
# Epoch 34/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.6118 - tp: 1064.4882 - fp: 566.6240 - tn: 1960.5325 - fn: 306.8553 - accuracy: 0.7757 - precision: 0.6523 - recall: 0.7760 - auc: 0.8550
# Epoch 00033: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.33.hdf5
# 1017/1017 [==============================] - 775s 762ms/step - loss: 0.6119 - tp: 1064.6392 - fp: 566.6883 - tn: 1960.7856 - fn: 306.8869 - accuracy: 0.7758 - precision: 0.6523 - recall: 0.7760 - auc: 0.8551 - val_loss: 0.2558 - val_tp: 1225.9027 - val_fp: 648.8672 - val_tn: 2243.3362 - val_fn: 345.8938 - val_accuracy: 0.7772 - val_precision: 0.6539 - val_recall: 0.7799 - val_auc: 0.8562
#
# Epoch 00034: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.34.hdf5
# Epoch 35/50
# 1017/1017 [==============================] - 774s 761ms/step - loss: 0.5938 - tp: 1392.6166 - fp: 724.3431 - tn: 2530.2576 - fn: 381.7827 - accuracy: 0.7799 - precision: 0.6576 - recall: 0.7847 - auc: 0.8591 - val_loss: 0.8226 - val_tp: 1549.6106 - val_fp: 797.2655 - val_tn: 2827.7876 - val_fn: 419.3363 - val_accuracy: 0.7825 - val_precision: 0.6603 - val_recall: 0.7870 - val_auc: 0.8611
#
# Epoch 00035: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.35.hdf5
# Epoch 36/50
# 1017/1017 [==============================] - 774s 761ms/step - loss: 0.5553 - tp: 1727.3077 - fp: 864.2950 - tn: 3120.3088 - fn: 447.0885 - accuracy: 0.7870 - precision: 0.6663 - recall: 0.7942 - auc: 0.8664 - val_loss: 2.3124 - val_tp: 1886.5221 - val_fp: 929.6725 - val_tn: 3426.3452 - val_fn: 481.4602 - val_accuracy: 0.7901 - val_precision: 0.6699 - val_recall: 0.7967 - val_auc: 0.8697
#
# Epoch 00036: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.36.hdf5
# Epoch 37/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.5216 - tp: 2034.7156 - fp: 985.9960 - tn: 3752.6545 - fn: 515.1339 - accuracy: 0.7939 - precision: 0.6734 - recall: 0.7979 - auc: 0.8735
# Epoch 00036: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.36.hdf5
# 1017/1017 [==============================] - 773s 760ms/step - loss: 0.5214 - tp: 2034.8860 - fp: 986.0433 - tn: 3752.9126 - fn: 515.1583 - accuracy: 0.7939 - precision: 0.6734 - recall: 0.7979 - auc: 0.8735 - val_loss: 0.2213 - val_tp: 2217.5840 - val_fp: 1047.4513 - val_tn: 4041.1858 - val_fn: 547.7787 - val_accuracy: 0.7969 - val_precision: 0.6792 - val_recall: 0.8019 - val_auc: 0.8769
#
# Epoch 00037: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.37.hdf5
# Epoch 38/50
# 1017/1017 [==============================] - 774s 762ms/step - loss: 0.5057 - tp: 2391.7012 - fp: 1099.3579 - tn: 4354.7505 - fn: 573.1907 - accuracy: 0.8012 - precision: 0.6849 - recall: 0.8066 - auc: 0.8809 - val_loss: 1.9295 - val_tp: 2558.9470 - val_fp: 1148.3717 - val_tn: 4672.3096 - val_fn: 604.3717 - val_accuracy: 0.8049 - val_precision: 0.6902 - val_recall: 0.8089 - val_auc: 0.8843
#
# Epoch 00038: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.38.hdf5
# Epoch 39/50
# 1017/1017 [==============================] - 773s 760ms/step - loss: 0.4612 - tp: 2741.7285 - fp: 1191.0393 - tn: 4993.0601 - fn: 623.1721 - accuracy: 0.8099 - precision: 0.6970 - recall: 0.8147 - auc: 0.8895 - val_loss: 0.6684 - val_tp: 2908.9734 - val_fp: 1239.6903 - val_tn: 5317.5400 - val_fn: 647.7964 - val_accuracy: 0.8134 - val_precision: 0.7012 - val_recall: 0.8179 - val_auc: 0.8926
#
# Epoch 00039: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.39.hdf5
# Epoch 40/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.4407 - tp: 3079.1812 - fp: 1279.3544 - tn: 5648.9517 - fn: 671.0128 - accuracy: 0.8173 - precision: 0.7064 - recall: 0.8210 - auc: 0.8958
# Epoch 00039: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.39.hdf5
# 1017/1017 [==============================] - 774s 761ms/step - loss: 0.4405 - tp: 3079.3560 - fp: 1279.3824 - tn: 5649.2378 - fn: 671.0236 - accuracy: 0.8173 - precision: 0.7064 - recall: 0.8210 - auc: 0.8958 - val_loss: 0.2923 - val_tp: 3265.3540 - val_fp: 1318.2035 - val_tn: 5970.9824 - val_fn: 689.4602 - val_accuracy: 0.8214 - val_precision: 0.7124 - val_recall: 0.8257 - val_auc: 0.8993
#
# Epoch 00040: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.40.hdf5
# Epoch 41/50
# 1017/1017 [==============================] - 773s 760ms/step - loss: 0.4206 - tp: 3449.4543 - fp: 1350.4493 - tn: 6300.0581 - fn: 709.0383 - accuracy: 0.8255 - precision: 0.7186 - recall: 0.8294 - auc: 0.9024 - val_loss: 0.2112 - val_tp: 3622.9292 - val_fp: 1392.5575 - val_tn: 6629.4336 - val_fn: 729.0797 - val_accuracy: 0.8285 - val_precision: 0.7224 - val_recall: 0.8325 - val_auc: 0.9052
#
# Epoch 00041: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.41.hdf5
# Epoch 42/50
# 1017/1017 [==============================] - 773s 760ms/step - loss: 0.4146 - tp: 3800.2715 - fp: 1431.8761 - tn: 6959.6167 - fn: 747.2360 - accuracy: 0.8315 - precision: 0.7263 - recall: 0.8356 - auc: 0.9080 - val_loss: 0.1990 - val_tp: 3981.7700 - val_fp: 1463.9292 - val_tn: 7290.3184 - val_fn: 767.9823 - val_accuracy: 0.8347 - val_precision: 0.7312 - val_recall: 0.8383 - val_auc: 0.9105
#
# Epoch 00042: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.42.hdf5
# Epoch 43/50
# 1017/1017 [==============================] - 773s 760ms/step - loss: 0.3839 - tp: 4157.3452 - fp: 1490.6047 - tn: 7634.9019 - fn: 786.1485 - accuracy: 0.8381 - precision: 0.7360 - recall: 0.8409 - auc: 0.9133 - val_loss: 1.0399 - val_tp: 4342.2920 - val_fp: 1521.1770 - val_tn: 7969.0532 - val_fn: 801.4779 - val_accuracy: 0.8413 - val_precision: 0.7406 - val_recall: 0.8442 - val_auc: 0.9158
#
# Epoch 00043: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.43.hdf5
# Epoch 44/50
# 1017/1017 [==============================] - 772s 759ms/step - loss: 0.3955 - tp: 4531.4639 - fp: 1551.1711 - tn: 8299.9219 - fn: 816.4425 - accuracy: 0.8442 - precision: 0.7449 - recall: 0.8473 - auc: 0.9183 - val_loss: 0.2372 - val_tp: 4705.7612 - val_fp: 1585.6283 - val_tn: 8638.8232 - val_fn: 833.7876 - val_accuracy: 0.8465 - val_precision: 0.7480 - val_recall: 0.8495 - val_auc: 0.9200
# 1017/1017 [==============================]
# Epoch 00044: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.44.hdf5
# Epoch 45/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3646 - tp: 4887.5176 - fp: 1604.7185 - tn: 8993.2148 - fn: 843.0492 - accuracy: 0.8501 - precision: 0.7528 - recall: 0.8528 - auc: 0.9228
# Epoch 00044: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.44.hdf5
# 1017/1017 [==============================] - 774s 761ms/step - loss: 0.3654 - tp: 4887.6992 - fp: 1604.7384 - tn: 8993.5049 - fn: 843.0580 - accuracy: 0.8501 - precision: 0.7528 - recall: 0.8528 - auc: 0.9228 - val_loss: 1.5235 - val_tp: 5081.9204 - val_fp: 1644.8761 - val_tn: 9309.9199 - val_fn: 857.2832 - val_accuracy: 0.8519 - val_precision: 0.7555 - val_recall: 0.8557 - val_auc: 0.9241
#
# Epoch 00045: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.45.hdf5
# Epoch 46/50
# 1017/1017 [==============================] - 772s 759ms/step - loss: 0.3376 - tp: 5263.3745 - fp: 1672.7030 - tn: 9654.6982 - fn: 868.2242 - accuracy: 0.8544 - precision: 0.7588 - recall: 0.8584 - auc: 0.9261 - val_loss: 2.4898 - val_tp: 5455.5840 - val_fp: 1692.4425 - val_tn: 9995.8145 - val_fn: 880.1593 - val_accuracy: 0.8573 - val_precision: 0.7632 - val_recall: 0.8611 - val_auc: 0.9283
#
# Epoch 00046: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.46.hdf5
# Epoch 47/50
# 1016/1017 [============================>.] - ETA: 0s - loss: 0.3451 - tp: 5643.4429 - fp: 1711.1427 - tn: 10342.4121 - fn: 891.5020 - accuracy: 0.8600 - precision: 0.7673 - recall: 0.8635 - auc: 0.9302
# Epoch 00046: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.46.hdf5
# 1017/1017 [==============================] - 774s 761ms/step - loss: 0.3449 - tp: 5643.6177 - fp: 1711.1593 - tn: 10342.7158 - fn: 891.5074 - accuracy: 0.8600 - precision: 0.7673 - recall: 0.8635 - auc: 0.9302 - val_loss: 0.1996 - val_tp: 5832.3540 - val_fp: 1743.7345 - val_tn: 10676.9297 - val_fn: 900.9823 - val_accuracy: 0.8619 - val_precision: 0.7698 - val_recall: 0.8662 - val_auc: 0.9317
#
# Epoch 00047: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.47.hdf5
# Epoch 48/50
# 1017/1017 [==============================] - 776s 763ms/step - loss: 0.3309 - tp: 6022.3813 - fp: 1770.0767 - tn: 11015.7891 - fn: 910.7532 - accuracy: 0.8640 - precision: 0.7728 - recall: 0.8686 - auc: 0.9333 - val_loss: 0.2897 - val_tp: 6207.4512 - val_fp: 1792.7699 - val_tn: 11361.2656 - val_fn: 922.5132 - val_accuracy: 0.8661 - val_precision: 0.7759 - val_recall: 0.8706 - val_auc: 0.9349
#
# Epoch 00048: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.48.hdf5
# Epoch 49/50
# 1017/1017 [==============================] - 777s 764ms/step - loss: 0.3214 - tp: 6402.0000 - fp: 1813.7090 - tn: 11701.1094 - fn: 932.1819 - accuracy: 0.8683 - precision: 0.7792 - recall: 0.8729 - auc: 0.9365 - val_loss: 3.0867 - val_tp: 6584.5308 - val_fp: 1838.0531 - val_tn: 12048.6553 - val_fn: 942.7610 - val_accuracy: 0.8701 - val_precision: 0.7818 - val_recall: 0.8748 - val_auc: 0.9379
#
# Epoch 00049: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.49.hdf5
# Epoch 50/50
# 1017/1017 [==============================] - 776s 763ms/step - loss: 0.3140 - tp: 6781.6836 - fp: 1853.3560 - tn: 12394.6846 - fn: 949.2763 - accuracy: 0.8725 - precision: 0.7853 - recall: 0.8772 - auc: 0.9395 - val_loss: 4.0804 - val_tp: 6969.6816 - val_fp: 1875.5133 - val_tn: 12742.7344 - val_fn: 956.0708 - val_accuracy: 0.8744 - val_precision: 0.7880 - val_recall: 0.8794 - val_auc: 0.9408
#
# Epoch 00050: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/meniscus/coronal/weights.50.hdf5

# %% [markdown]
# # **testing on validation dataset**

# %%
label_type = 'meniscus'
exam_view = 'coronal'
model, cbs = MRNet_inc_model(1,0,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception/"+label_type+"/"+exam_view+"/weights.75.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])

neg = total - pos
class_count_valid = {0: neg, 1: pos}

batch_size = 1
print(model.metrics_names)
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , batch_size=1,model="inception",data_type='valid', shuffle=False,label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
d = model.evaluate_generator(valid_data_gen, total, verbose=1)
print(d)
model.predict_generator(valid_data_gen, 5, verbose=1)
# Out:
# no dropout
# no dropout
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21804833
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# ['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc']
# Initializing Data Generator:
# factor :  1.3076923076923077
# model:  inception
# data type:  valid
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (299, 299)
# 120/120 [==============================] - 117s 973ms/step
# [2.009526491165161, 12.266666412353516, 5.108333110809326, 30.75, 12.375, 0.7421681880950928, 0.7909902930259705, 0.5024921298027039, 0.7369959354400635]
# 5/5 [==============================] - 4s 702ms/step
# array([[0.10508177],
#        [0.10746955],
#        [0.02542444],
#        [0.93907094],
#        [0.32079354]], dtype=float32)

# %% [markdown]
# valid : [2.009, 12.266, 5.108, 30.75, 12.375, 0.7421, 0.7909902930259705,
# 0.50249, 0.73699]
